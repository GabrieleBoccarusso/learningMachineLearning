# %% [markdown]
# [dataset](https://www.kaggle.com/rashikrahmanpritom/177k-english-song-data-from-20082017)

# %%
import pandas as pd

data = pd.read_csv('data/songs.csv')
data.head()
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
# 3                  NaN       193          0      Rock      [25]  ...
# 4  2008-11-26 00:00:00       405          5      Rock      [26]  ...
#
#   information interest  language_code  \
# 0         NaN     2484             en
# 1         NaN     1948             en
# 2         NaN      701             en
# 3         NaN      637             en
# 4         NaN      354             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
#
# [5 rows x 21 columns]

# %% [markdown]
# task: binary classification between rock and hip-pop songs

# %%
data.isna().sum()
# Out:
# track_id             0
# bit_rate             0
# comments             0
# composer         17568
# date_created         0
# date_recorded    15836
# duration             0
# favorites            0
# genre_top            0
# genres               0
# genres_all           0
# information      17252
# interest             0
# language_code    13645
# license             20
# listens              0
# lyricist         17681
# number               0
# publisher        17682
# tags                 0
# title                0
# dtype: int64

# %% [markdown]
# feature report:
# - numerical:
#     * track_id: 0
#     * bit_rate: mean
#     * comments: 0
#     * duration: mean
#     * favorites: 0
#     * interest: 0
#     * listens: 0
# - categorical:
#     * composer: 'missing'
#     * date_created: 'missing'
#     * date_recorded: 'missing'
#     * genre_top: TO CLASSIFY
#     * information: 'missing'
#     * language_code: 'missing'
#     * license: 'missing'
#     * lyricist: 'missing'
#     * publisher: 'missing'
#     * tags: 'missing'
#     * title: 'missing'

# %%
data.keys()
https://www.kaggle.com/rashikrahmanpritom/177k-english-song-data-from-20082017
# Out:
# Index(['track_id', 'bit_rate', 'comments', 'composer', 'date_created',
#        'date_recorded', 'duration', 'favorites', 'genre_top', 'genres',
#        'genres_all', 'information', 'interest', 'language_code', 'license',
#        'listens', 'lyricist', 'number', 'publisher', 'tags', 'title'],
#       dtype='object')

# %%
# clean data importing
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# classification importing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# if this data is missing its value will be zero
zero_value_features = ['track_id', 'comments', 'favorites', 'interest', 'listens']
zero_value_transformer = Pipeline(steps = [
    ('zero_imputer', SimpleImputer(strategy = 'constant', fill_value = 0))
])

# if this data is missing its value will be the mean
mean_value_features = ['bit_rate', 'duration']
mean_value_transformer = Pipeline(steps = [
    ('mean_imputer', SimpleImputer(strategy = 'mean'))
])

# if this data is missing their value will be 'missing'
missing_value_features =  ['composer', 'date_created', 'date_recorded',
                           'information', 'language_code', 'license', 'lyricist', 'publisher', 'tags', 'title']
missing_value_transformer = Pipeline(steps = [
    ('missing_imputer', SimpleImputer(strategy = 'constant', fill_value = 'missing')),
    ('onehot', OneHotEncoder(handle_unknown = 'ignore'))
])
preprocessor = ColumnTransformer(
    transformers = [
    # ('numerical', numerical_transformer, num_features)
    ('zero_value', zero_value_transformer, zero_value_features),
    ('mean_value', mean_value_transformer, mean_value_features),
    ('missing_value', missing_value_transformer ,missing_value_features)
], remainder = 'passthrough', verbose = 2)

model = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier())
])

# split data 
# genre_top is dropped because is the column to predict,
# the others because are in a very strange format
X = data.drop(['genre_top', 'number', 'genres_all', 'genres'],axis = 1)
y = data.genre_top
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .15)

model.fit(X_train, y_train);
# Out:
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s

# %%
model.score(X_test, y_test) * 100
# Out:
# 91.99549041713641

# %%
from sklearn.model_selection import GridSearchCV

# using the grid with the pipeline
pipe_grid = {
    'preprocessor__mean_value__mean_imputer__strategy': ['mean', 'median'],
    'model__n_estimators': [100, 200],
    'model__min_samples_split': [2, 4],
    'model__min_samples_leaf': [1, 2],
    'model__max_features': ['auto', 'sqrt']
}

gs_model = GridSearchCV(model, pipe_grid, cv = 5, verbose = 2)
gs_model.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  22.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  25.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  20.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  17.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  18.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  34.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  29.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.1s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  30.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  23.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  19.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.1s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  36.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  42.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  43.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  43.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  45.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  44.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  45.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  44.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  46.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  43.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  16.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  15.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  18.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  22.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  19.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  18.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  17.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  17.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  18.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  16.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  34.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  33.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  34.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  35.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  36.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  36.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  37.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  40.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  39.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  38.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   2.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   2.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   2.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.5s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   2.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   2.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   4.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   4.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   2.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   6.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   4.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=auto, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   5.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  44.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  39.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  28.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  22.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  26.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  23.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  21.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  23.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  23.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  26.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  47.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time= 1.2min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  44.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  51.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  44.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  49.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  58.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time= 1.4min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time= 1.2min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time= 1.3min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  37.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  41.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.5s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  33.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  36.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  29.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  33.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  42.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  34.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  35.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=  30.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time= 1.1min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time= 1.1min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time= 1.1min
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  48.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=  37.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  36.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  35.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=1, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=  36.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# ...
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   2.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.3s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.8s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   1.9s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.6s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=100, preprocessor__mean_value__mean_imputer__strategy=median; total time=   1.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.7s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.5s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=mean; total time=   3.2s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.0s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.4s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=2, model__min_samples_split=4, model__n_estimators=200, preprocessor__mean_value__mean_imputer__strategy=median; total time=   3.1s
# [ColumnTransformer] .... (1 of 3) Processing zero_value, total=   0.0s
# [ColumnTransformer] .... (2 of 3) Processing mean_value, total=   0.0s
# [ColumnTransformer] . (3 of 3) Processing missing_value, total=   0.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('zero_value',
#                                                                          Pipeline(steps=[('zero_imputer',
#                                                                                           SimpleImputer(fill_value=0,
#                                                                                                         strategy='constant'))]),
#                                                                          ['track_id',
#                                                                           'comments',
#                                                                           'favorites',
#                                                                           'interest',
#                                                                           'listens']),
#                                                                         ('mean_value',
#                                                                          Pipeline(steps=[('mean_imputer',
#                                                                                           SimpleImputer())]),
#                                                                          ['bit_rate',
#                                                                           'd...
#                                                                           'information',
#                                                                           'language_code',
#                                                                           'license',
#                                                                           'lyricist',
#                                                                           'publisher',
#                                                                           'tags',
#                                                                           'title'])],
#                                                           verbose=2)),
#                                        ('model', RandomForestClassifier())]),
#              param_grid={'model__max_features': ['auto', 'sqrt'],
#                          'model__min_samples_leaf': [1, 2],
#                          'model__min_samples_split': [2, 4],
#                          'model__n_estimators': [100, 200],
#                          'preprocessor__mean_value__mean_imputer__strategy': ['mean',
#                                                                               'median']},
#              verbose=2)

# %%
gs_model.score(X_test, y_test) * 100
# Out:
# 91.8075911311537
