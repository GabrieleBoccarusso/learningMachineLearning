# %% [markdown]
# ## Are you ready?

# %%
import pandas as pd

# %%
# baseball players
series = pd.Series(["Adam Donachie", "Kevin Millar", "Brian Roberts"])

# %%
series # this will show the data type
# Out:
# 0    Adam Donachie
# 1     Kevin Millar
# 2    Brian Roberts
# dtype: object

# %%
position = pd.Series([ "Catcher",  "First Baseman",  "Second Baseman"])
position
# Out:
# 0           Catcher
# 1     First Baseman
# 2    Second Baseman
# dtype: object

# %%
# data frame are 2 dimensional and are more common than series
baseball_data = pd.DataFrame({"Player name": series, "Position": position})

# %%
baseball_data
# Out:
#      Player name        Position
# 0  Adam Donachie         Catcher
# 1   Kevin Millar   First Baseman
# 2  Brian Roberts  Second Baseman

# %%
bb_players = pd.read_csv("baseball_players.csv")
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
# exporting a DataFrame
bb_players.to_csv("exported-bb-players.csv", index = False)
exported_bb_players = pd.read_csv("exported-bb-players.csv")
exported_bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players.dtypes
# Out:
# Name                object
# Team                object
# Position            object
# Height (inches)      int64
# Weight (lbs)         int64
# Age                float64
# salary              object
# dtype: object

# %%
bb_players = pd.read_csv("baseball_players.csv")

# %%
bb_players.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Height (inches)', 'Weight (lbs)', 'Age',
#        'salary'],
#       dtype='object')

# %%
bb_players_columns = bb_players.columns
bb_players_columns
# Out:
# Index(['Name', 'Team', 'Position', 'Height (inches)', 'Weight (lbs)', 'Age',
#        'salary'],
#       dtype='object')

# %%
bb_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             9 non-null      object
#  1   Team             9 non-null      object
#  2   Position         9 non-null      object
#  3   Height (inches)  9 non-null      int64
#  4   Weight (lbs)     9 non-null      int64
#  5   Age              9 non-null      float64
#  6   salary           9 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 632.0+ bytes

# %%
bb_players.mean()
# Out:
# Height (inches)     72.222222
# Weight (lbs)       202.111111
# Age                 31.668889
# dtype: float64

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players.sum()
# Out:
# Name               Adam DonachiePaul BakoRamon HernandezKevin Mil...
# Team                             BAL BAL BAL BAL BAL BAL BAL BAL BAL
# Position            Catcher Catcher Catcher First Baseman First B...
# Height (inches)                                                  650
# Weight (lbs)                                                    1819
# Age                                                           285.02
# salary             $25.124.00$24.256.00$22.467.00$27.592.00$29.44...
# dtype: object

# %%
len(bb_players)
# Out:
# 9

# %%
bb_players.head()
# Out:
#               Name  Team        Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL         Catcher               74           180
# 1        Paul Bako   BAL         Catcher               74           215
# 2  Ramon Hernandez   BAL         Catcher               72           210
# 3     Kevin Millar   BAL   First Baseman               72           210
# 4      Chris Gomez   BAL   First Baseman               73           188
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00

# %%
bb_players.tail(4)
# Out:
#             Name  Team         Position  Height (inches)  Weight (lbs)    Age  \
# 5  Brian Roberts   BAL   Second Baseman               69           176  29.39
# 6  Miguel Tejada   BAL        Shortstop               69           209  30.77
# 7    Melvin Mora   BAL    Third Baseman               71           200  35.07
# 8    Aubrey Huff   BAL    Third Baseman               76           231  30.19
#
#        salary
# 5  $25.937.00
# 6  $24.924.00
# 7  $28.963.00
# 8  $22.996.00

# %%
people = pd.Series(["John", "Mark", "Pierre", "Stacy", "Chad"],
                    index = [4, 6, 4, 9, 2])
people
# Out:
# 4      John
# 6      Mark
# 4    Pierre
# 9     Stacy
# 2      Chad
# dtype: object

# %%
people.loc[4]
# Out:
# 4      John
# 4    Pierre
# dtype: object

# %%
people.iloc[4]
# Out:
# 'Chad'

# %%
bb_players["Name"]
# Out:
# 0      Adam Donachie
# 1          Paul Bako
# 2    Ramon Hernandez
# 3       Kevin Millar
# 4        Chris Gomez
# 5      Brian Roberts
# 6      Miguel Tejada
# 7        Melvin Mora
# 8        Aubrey Huff
# Name: Name, dtype: object

# %%
bb_players.Name
# Out:
# 0      Adam Donachie
# 1          Paul Bako
# 2    Ramon Hernandez
# 3       Kevin Millar
# 4        Chris Gomez
# 5      Brian Roberts
# 6      Miguel Tejada
# 7        Melvin Mora
# 8        Aubrey Huff
# Name: Name, dtype: object

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players[bb_players.Position == "Catcher"]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Position, Height (inches), Weight (lbs), Age, salary]
# Index: []

# %%
bb_players.mean()
# Out:
# Height (inches)     72.222222
# Weight (lbs)       202.111111
# Age                 31.668889
# dtype: float64

# %%
bb_players[bb_players.Name > 20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-9bb952165067> in <module>
# ----> 1 bb_players[bb_players.Name > 20]
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      43     @unpack_zerodim_and_defer("__gt__")
#      44     def __gt__(self, other):
# ---> 45         return self._cmp_method(other, operator.gt)
#      46
#      47     @unpack_zerodim_and_defer("__ge__")
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4946         rvalues = extract_array(other, extract_numpy=True)
#    4947
# ...

# %%
bb_players

# %%
bb_players.dtypes

# %%
bb_players[" Team"]

# %%
bb_players = pd.read_csv("baseball_players.csv")

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players.Age
# Out:
# 0    22.99
# 1    34.69
# 2    30.78
# 3    35.43
# 4    35.71
# 5    29.39
# 6    30.77
# 7    35.07
# 8    30.19
# Name: Age, dtype: float64

# %%
pd.crosstab(bb_players["Position"], bb_players["Weight (lbs)"])
# Out:
# Weight (lbs)     176  180  188  200  209  210  215  231
# Position
#  Catcher           0    1    0    0    0    1    1    0
#  First Baseman     0    0    1    0    0    1    0    0
#  Second Baseman    1    0    0    0    0    0    0    0
#  Third Baseman     0    0    0    1    0    0    0    1
# Shortstop          0    0    0    0    1    0    0    0

# %%
bb_players.groupby(["Position"]).mean()
# Out:
#                  Height (inches)  Weight (lbs)        Age
# Position
#  Catcher               73.333333    201.666667  29.486667
#  First Baseman         72.500000    199.000000  35.570000
#  Second Baseman        69.000000    176.000000  29.390000
#  Third Baseman         73.500000    215.500000  32.630000
# Shortstop              69.000000    209.000000  30.770000

# %%
bb_players["Weight (lbs)"].plot()
# Out:
# <AxesSubplot:>

# %%
bb_players.plot(x="Height (inches)", y="Weight (lbs)")
# Out:
# <AxesSubplot:xlabel='Height (inches)'>

# %%
bb_players["Height (inches)"].hist()
# Out:
# <AxesSubplot:>

# %%
bb_players["Age"].plot()
# Out:
# <AxesSubplot:>

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players["Age"].astype(int)
# Out:
# 0    22
# 1    34
# 2    30
# 3    35
# 4    35
# 5    29
# 6    30
# 7    35
# 8    30
# Name: Age, dtype: int32

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players.dtypes
# Out:
# Name                object
# Team                object
# Position            object
# Height (inches)      int64
# Weight (lbs)         int64
# Age                float64
# salary              object
# dtype: object

# %%
bb_players_new["salary"].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-6d5bfd8a5230> in <module>
# ----> 1 bb_players_new["salary"].plot()
#
# NameError: name 'bb_players_new' is not defined

# %%
# let's copy the original as comment 
# dataframe['amount'] = dataframe['amount'].replace('[\$\,\.]', '', regex=True).astype(int)

# %%
# then let's rewrite it but with our data
#bb_players_new["salary"] = bb_players_new["salary"].str.replace('[\$\,\.]', '', regex=True).astype(int)

# %%
bb_players_new = pd.read_csv("baseball_players.csv")
bb_players_new
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
# let's copy the original as comment 
# dataframe['amount'] = dataframe['amount'].replace('[\$\,\.]', '', regex=True).astype(int)

# %%
# then let's rewrite it but with our data
bb_players_new["salary"] = bb_players_new["salary"].str.replace('[\$\,\.]', '', regex=True).astype(int)

# %%
bb_players_new["salary"] = bb_players_new["salary"].str.replace('[\$\,\.]', '', regex=True).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-3141405855dd> in <module>
# ----> 1 bb_players_new["salary"] = bb_players_new["salary"].str.replace('[\$\,\.]', '', regex=True).astype(float)
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5456             or name in self._accessors
#    5457         ):
# -> 5458             return object.__getattribute__(self, name)
#    5459         else:
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %%
bb_players_new

# %%
bb_players_new.salary.astype(int)
# Out:
# 0    2512400
# 1    2425600
# 2    2246700
# 3    2759200
# 4    2944900
# 5    2593700
# 6    2492400
# 7    2896300
# 8    2299600
# Name: salary, dtype: int32

# %%
import numpy as np

# %%
bb_players_new["salary"].dtype = np.int
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Desktop\sample\env\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5492                 else:
# -> 5493                     object.__setattr__(self, name, value)
#    5494             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-485c646a3829> in <module>
# ----> 1 bb_players_new["salary"].dtype = np.int
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5501                         stacklevel=2,
#    5502                     )
# -> 5503                 object.__setattr__(self, name, value)
#    5504
#    5505     @final
#
# ...

# %%
bb_players_new = pd.read_csv("baseball_players.csv")

# %%
bb_players_new
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age      salary
# 0  22.99  $25.124.00
# 1  34.69  $24.256.00
# 2  30.78  $22.467.00
# 3  35.43  $27.592.00
# 4  35.71  $29.449.00
# 5  29.39  $25.937.00
# 6  30.77  $24.924.00
# 7  35.07  $28.963.00
# 8  30.19  $22.996.00

# %%
bb_players_new["salary"] = bb_players_new["salary"].str.replace('[\$\,\.]', '', regex=True).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-3141405855dd> in <module>
# ----> 1 bb_players_new["salary"] = bb_players_new["salary"].str.replace('[\$\,\.]', '', regex=True).astype(float)
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5456             or name in self._accessors
#    5457         ):
# -> 5458             return object.__getattribute__(self, name)
#    5459         else:
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Desktop\sample\env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %%
bb_players_new

# %%
bb_players_new["salary"].dtype = np.int64

# %%
bb_players = pd.read_csv("baseball_players.csv")

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age
# 0  22.99
# 1  34.69
# 2  30.78
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8  30.19

# %%
bb_players["Name"].str.lower()
# Out:
# 0      adam donachie
# 1          paul bako
# 2    ramon hernandez
# 3       kevin millar
# 4        chris gomez
# 5      brian roberts
# 6      miguel tejada
# 7        melvin mora
# 8        aubrey huff
# Name: Name, dtype: object

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL          Catcher               74           180
# 1        Paul Bako   BAL          Catcher               74           215
# 2  Ramon Hernandez   BAL          Catcher               72           210
# 3     Kevin Millar   BAL    First Baseman               72           210
# 4      Chris Gomez   BAL    First Baseman               73           188
# 5    Brian Roberts   BAL   Second Baseman               69           176
# 6    Miguel Tejada   BAL        Shortstop               69           209
# 7      Melvin Mora   BAL    Third Baseman               71           200
# 8      Aubrey Huff   BAL    Third Baseman               76           231
#
#      Age
# 0  22.99
# 1  34.69
# 2  30.78
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8  30.19

# %%
bb_players["Name"] = bb_players["Name"].str.lower()
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age
# 0  22.99
# 1  34.69
# 2  30.78
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8  30.19

# %%
bb_players_missing_data = pd.read_csv("baseball_players_missing_data.csv")
bb_players_missing_data
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL              NaN             74.0         180.0
# 1        Paul Bako   BAL          Catcher              NaN         215.0
# 2  Ramon Hernandez   BAL          Catcher             72.0         210.0
# 3     Kevin Millar   NaN    First Baseman             72.0           NaN
# 4      Chris Gomez   NaN    First Baseman              NaN           NaN
# 5    Brian Roberts   BAL   Second Baseman             69.0         176.0
# 6    Miguel Tejada   BAL        Shortstop              NaN           NaN
# 7      Melvin Mora   BAL    Third Baseman             71.0         200.0
# 8      Aubrey Huff   NaN    Third Baseman             76.0         231.0
#
#      Age
# 0  22.99
# 1  34.69
# 2    NaN
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8    NaN

# %%
bb_players_missing_data["Height (inches)"].mean()
# Out:
# 72.33333333333333

# %%
bb_players_missing_data["Height (inches)"].fillna(bb_players_missing_data["Height (inches)"].mean())
# Out:
# 0    74.000000
# 1    72.333333
# 2    72.000000
# 3    72.000000
# 4    72.333333
# 5    69.000000
# 6    72.333333
# 7    71.000000
# 8    76.000000
# Name: Height (inches), dtype: float64

# %%
bb_players_missing_data["Height (inches)"].fillna(bb_players_missing_data["Height (inches)"].mean(), inplace = True)
bb_players_missing_data
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    Adam Donachie   BAL              NaN        74.000000         180.0
# 1        Paul Bako   BAL          Catcher        72.333333         215.0
# 2  Ramon Hernandez   BAL          Catcher        72.000000         210.0
# 3     Kevin Millar   NaN    First Baseman        72.000000           NaN
# 4      Chris Gomez   NaN    First Baseman        72.333333           NaN
# 5    Brian Roberts   BAL   Second Baseman        69.000000         176.0
# 6    Miguel Tejada   BAL        Shortstop        72.333333           NaN
# 7      Melvin Mora   BAL    Third Baseman        71.000000         200.0
# 8      Aubrey Huff   NaN    Third Baseman        76.000000         231.0
#
#      Age
# 0  22.99
# 1  34.69
# 2    NaN
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8    NaN

# %%
bb_players_missing_data.dropna()
# Out:
#             Name  Team         Position  Height (inches)  Weight (lbs)    Age
# 1      Paul Bako   BAL          Catcher        72.333333         215.0  34.69
# 5  Brian Roberts   BAL   Second Baseman        69.000000         176.0  29.39
# 7    Melvin Mora   BAL    Third Baseman        71.000000         200.0  35.07

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age
# 0  22.99
# 1  34.69
# 2  30.78
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8  30.19

# %%
entry_year_column = pd.Series([1987, 1987, 1987, 1987, 1987])
bb_players["entry year"] = entry_year_column
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age  entry year
# 0  22.99      1987.0
# 1  34.69      1987.0
# 2  30.78      1987.0
# 3  35.43      1987.0
# 4  35.71      1987.0
# 5  29.39         NaN
# 6  30.77         NaN
# 7  35.07         NaN
# 8  30.19         NaN

# %%
bb_players.drop("entry year", axis = 1, inplace=True)
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age
# 0  22.99
# 1  34.69
# 2  30.78
# 3  35.43
# 4  35.71
# 5  29.39
# 6  30.77
# 7  35.07
# 8  30.19

# %%
entry_year_column = pd.Series([1987, 1987, 1987, 1987, 1987])
bb_players["entry year"] = entry_year_column
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age  entry year
# 0  22.99      1987.0
# 1  34.69      1987.0
# 2  30.78      1987.0
# 3  35.43      1987.0
# 4  35.71      1987.0
# 5  29.39         NaN
# 6  30.77         NaN
# 7  35.07         NaN
# 8  30.19         NaN

# %%
bb_players.fillna(1987, inplace = True)
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age  entry year
# 0  22.99      1987.0
# 1  34.69      1987.0
# 2  30.78      1987.0
# 3  35.43      1987.0
# 4  35.71      1987.0
# 5  29.39      1987.0
# 6  30.77      1987.0
# 7  35.07      1987.0
# 8  30.19      1987.0

# %%
begin_age = [1965, 1953, 1957, 1952, 1952, 1956, 1957, 1952, 1957]
bb_players["entry age"] = begin_age
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age  entry year  entry age
# 0  22.99      1987.0       1965
# 1  34.69      1987.0       1953
# 2  30.78      1987.0       1957
# 3  35.43      1987.0       1952
# 4  35.71      1987.0       1952
# 5  29.39      1987.0       1956
# ...

# %%
bb_players["height-weight ratio"] = (bb_players["Height (inches)"] + bb_players["Weight (lbs)"])/ 2
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age  entry year  entry age  height-weight ratio
# 0  22.99      1987.0       1965                127.0
# 1  34.69      1987.0       1953                144.5
# 2  30.78      1987.0       1957                141.0
# ...

# %%
bb_players["hands"] = 2
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#      Age  entry year  entry age  height-weight ratio  hands
# 0  22.99      1987.0       1965                127.0      2
# 1  34.69      1987.0       1953                144.5      2
# ...

# %%
bb_players.drop("Age", axis = 1, inplace = True)
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#    entry year  entry age  height-weight ratio  hands
# 0      1987.0       1965                127.0      2
# 1      1987.0       1953                144.5      2
# 2      1987.0       1957                141.0      2
# ...

# %%
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74           180
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 3     kevin millar   BAL    First Baseman               72           210
# 4      chris gomez   BAL    First Baseman               73           188
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 7      melvin mora   BAL    Third Baseman               71           200
# 8      aubrey huff   BAL    Third Baseman               76           231
#
#    entry year  entry age  height-weight ratio  hands
# 0      1987.0       1965                127.0      2
# 1      1987.0       1953                144.5      2
# 2      1987.0       1957                141.0      2
# ...

# %%
shuffled_players = bb_players.sample(frac=1)
shuffled_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 8      aubrey huff   BAL    Third Baseman               76           231
# 0    adam donachie   BAL          Catcher               74           180
# 4      chris gomez   BAL    First Baseman               73           188
# 1        paul bako   BAL          Catcher               74           215
# 2  ramon hernandez   BAL          Catcher               72           210
# 7      melvin mora   BAL    Third Baseman               71           200
# 5    brian roberts   BAL   Second Baseman               69           176
# 6    miguel tejada   BAL        Shortstop               69           209
# 3     kevin millar   BAL    First Baseman               72           210
#
#    entry year  entry age  height-weight ratio  hands
# 8      1987.0       1957                153.5      2
# 0      1987.0       1965                127.0      2
# 4      1987.0       1952                130.5      2
# ...

# %%
shuffled_players.sample(frac = 0.6)# shuffling the 60 percent of the DataFrame
# Out:
#               Name  Team        Position  Height (inches)  Weight (lbs)  \
# 2  ramon hernandez   BAL         Catcher               72           210
# 0    adam donachie   BAL         Catcher               74           180
# 4      chris gomez   BAL   First Baseman               73           188
# 7      melvin mora   BAL   Third Baseman               71           200
# 8      aubrey huff   BAL   Third Baseman               76           231
#
#    entry year  entry age  height-weight ratio  hands
# 2      1987.0       1957                141.0      2
# 0      1987.0       1965                127.0      2
# 4      1987.0       1952                130.5      2
# 7      1987.0       1952                135.5      2
# 8      1987.0       1957                153.5      2

# %%
shuffled_players.reset_index(drop=True)
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0      aubrey huff   BAL    Third Baseman               76           231
# 1    adam donachie   BAL          Catcher               74           180
# 2      chris gomez   BAL    First Baseman               73           188
# 3        paul bako   BAL          Catcher               74           215
# 4  ramon hernandez   BAL          Catcher               72           210
# 5      melvin mora   BAL    Third Baseman               71           200
# 6    brian roberts   BAL   Second Baseman               69           176
# 7    miguel tejada   BAL        Shortstop               69           209
# 8     kevin millar   BAL    First Baseman               72           210
#
#    entry year  entry age  height-weight ratio  hands
# 0      1987.0       1957                153.5      2
# 1      1987.0       1965                127.0      2
# 2      1987.0       1952                130.5      2
# ...

# %%
bb_players["Weight (lbs)"] = bb_players["Weight (lbs)"].apply(lambda x: x/0.45)
bb_players
# Out:
#               Name  Team         Position  Height (inches)  Weight (lbs)  \
# 0    adam donachie   BAL          Catcher               74    888.888889
# 1        paul bako   BAL          Catcher               74   1061.728395
# 2  ramon hernandez   BAL          Catcher               72   1037.037037
# 3     kevin millar   BAL    First Baseman               72   1037.037037
# 4      chris gomez   BAL    First Baseman               73    928.395062
# 5    brian roberts   BAL   Second Baseman               69    869.135802
# 6    miguel tejada   BAL        Shortstop               69   1032.098765
# 7      melvin mora   BAL    Third Baseman               71    987.654321
# 8      aubrey huff   BAL    Third Baseman               76   1140.740741
#
#    entry year  entry age  height-weight ratio  hands
# 0      1987.0       1965                127.0      2
# 1      1987.0       1953                144.5      2
# 2      1987.0       1957                141.0      2
# ...
